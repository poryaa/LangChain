# %%
from llm_core import answer_question
print(answer_question("whp are you?"))
# Out:
# content="Sure, I'm happy to provide some information! The WH-117RM is a popular line of wireless headphones that are known for their clear and crisp sound quality. They come with Bluetooth connectivity for easy pairing with compatible devices such as smartphones, laptops, or tablets. The headphones also feature active noise cancellation (ANC) technology to block out external noise and enhance the audio experience. Additionally, the WH-117RM supports advanced features like voice control and smart assistant compatibility through Amazon Alexa or Google Assistant, providing a seamless and convenient way to control your headphones through your smartphone or other voice-activated devices. Overall, the WH-117RM offers an exceptional audio experience for all users who appreciate high-quality sound." additional_kwargs={} response_metadata={'model': 'tinyllama:latest', 'created_at': '2026-02-28T15:25:56.07576618Z', 'done': True, 'done_reason': 'stop', 'total_duration': 10478946647, 'load_durat
# ...
